# %% [raw]
# # DHDMeetUp 2019.11.13 ŁÓDŹ

# %% [markdown]
# # DHDMeetUp 2019.11.13 ŁÓDŹ

# %% [raw]
# #### `TORNADO` Piotr Liberadzki, Łukasz Biernacki

# %% [markdown]
# #### `TORNADO` Piotr Liberadzki, Łukasz Biernacki

# %% [raw]
# ![logo_tornado](churn/logo_tornado.png)

# %% [markdown]
# ![logo_tornado](churn/logo_tornado.png)

# %% [raw]
# ### Jupyter - analiza i wizualizacja danych w notatniku

# %% [markdown]
# ### Jupyter - analiza i wizualizacja danych w notatniku

# %% [raw]
#  (\\(\Ju(lia)\), \\(\Py(thon)\), \\(e)\(\R\\))

# %% [markdown]
#  (\\(\Ju(lia)\), \\(\Py(thon)\), \\(e)\(\R\\))

# %% [raw]
# - głównie Python wraz z bibliotekami NumPy i SciPy,
# - R,
# - Julia,
#
# ale również inne:
#
# - JavaScript,
# - Java,
# - Scala,
# - Go,
# - C#,
# - Ruby,
# - Kotlin,
# - Haskell.

# %% [markdown]
# - głównie Python wraz z bibliotekami NumPy i SciPy,
# - R,
# - Julia,
#
# ale również inne:
#
# - JavaScript,
# - Java,
# - Scala,
# - Go,
# - C#,
# - Ruby,
# - Kotlin,
# - Haskell.

# %% [raw]
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [raw]
# | Fun                  | With                 | Tables          |
# | :------------------- | -------------------: |:---------------:|
# | left-aligned column  | right-aligned column | centered column |
# | $100                 | $100                 | $100            |
# | $10                  | $10                  | $10             |
# | $1                   | $1                   | $1              |

# %% [markdown]
# | Fun                  | With                 | Tables          |
# | :------------------- | -------------------: |:---------------:|
# | left-aligned column  | right-aligned column | centered column |
# | $100                 | $100                 | $100            |
# | $10                  | $10                  | $10             |
# | $1                   | $1                   | $1              |

# %% [markdown]
# # Predicting Churn for Bank Customers

# %% [markdown]
# ### Wczytanie bibliotek

# %%
pip install plotly #instalacja

# %%
import pandas as pd #analityka

import seaborn as sns #wizualizacja

import matplotlib.pyplot as plt  #wizualizacja
# %matplotlib inline

import plotly.offline as py  #wizualizacja
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go  #wizualizacja
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Wczytanie danych

# %%
df=pd.read_csv('churn/Churn_Modelling.csv', delimiter=',')

# %% [markdown]
# ![Dane z Kaggle](churn/churn.png)

# %% [markdown]
# ## Analiza

# %% [markdown]
# #### Początek pliku

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# #### Koniec pliku

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# #### Próbka danych

# %%
df.sample(5)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 4716       4717    15805764  Hallahan          646    France    Male   18
# 2852       2853    15771483    Arnold          609    France    Male   40
# 5699       5700    15624667   Wallace          684    France    Male   35
# 5420       5421    15583462    Graham          695    France    Male   28
# 761         762    15582741   Maclean          693    France  Female   35
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4716      10       0.00              2          0               1
# 2852       6       0.00              2          1               1
# 5699       6  135871.50              1          1               1
# 5420       5  171069.39              2          1               1
# 761        5  124151.09              1          1               0
#
#       EstimatedSalary  Exited
# 4716         52795.15       0
# 2852         97416.34       0
# ...

# %% [markdown]
# #### Ogólne informacje o zbiorze

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Statystyki

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# #### Rozkład zmiennych

# %%
df['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
df['Age'].hist(bins=50)

# %%
# wybieramy tych co odeszli
df[df['Exited']==1]['Age'].hist(bins=50)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
delete=['RowNumber', 'CustomerId', 'Surname']
columns= [col for col in df.columns if col not in delete]
columns
# Out:
# ['CreditScore',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited',
#  'credit_score_age',
#  'Gender_num']

# %%
df[columns].hist(figsize=(20,15), bins=50)
plt.show()

# %% [markdown]
# #### Liczba wartości unikalnych

# %%
df.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %% [markdown]
# #### Czy są nulle?

# %%
df.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
df.isnull().any().any()
# Out:
# False

# %% [markdown]
# #### Grupowanie

# %%
df.groupby(['Geography','Gender','Exited'])['Exited'].agg(['count'])
# Out:
#                          count
# Geography Gender Exited
# France    Female 0        1801
#                  1         460
#           Male   0        2403
#                  1         350
# Germany   Female 0         745
#                  1         448
#           Male   0         950
#                  1         366
# Spain     Female 0         858
#                  1         231
#           Male   0        1206
#                  1         182

# %%
df.groupby(['Geography','Exited'])['EstimatedSalary'].agg(['max','mean','median'])
# Out:
#                         max           mean      median
# Geography Exited
# France    0       199929.17   99217.097331   98045.045
#           1       199378.58  103439.278296  103739.240
# Germany   0       199970.74  102414.657876  103557.850
#           1       199808.10   98403.886450   96498.135
# Spain     0       199992.48   98602.369864   98768.455
#           1       199304.74  103629.554818  108732.960

# %% [markdown]
# #### Nowe kolumny

# %%
df['credit_score_age']= df['CreditScore']/df['Age']
df['Gender_num']=df['Gender'].apply(lambda x: 1 if x=='Female' else 0)

# %% [markdown]
# #### Usuwanie kolumn

# %%
for x in delete:
    del df[x]

# %% [markdown]
# ## Wizualizacja

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="Geography", y="Exited", hue='Gender', data=df)
plt.show();

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="Geography", y="Exited", hue='IsActiveMember', data=df)
plt.show();

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="Geography", y="Exited", hue='NumOfProducts', data=df)
plt.show();

# %% [markdown]
# Wszyscy klienci, którzy mieli cztery produkty odeszli?
#
# Sprawdźmy

# %%
df[df['NumOfProducts']==4]['Exited'].value_counts()
# Out:
# 1    60
# Name: Exited, dtype: int64

# %% [markdown]
# Na to wygląda...

# %% [markdown]
# #### Bardziej złożona wizualizacja

# %%
churn     = df[df["Exited"] == 1]
not_churn = df[df["Exited"] == 0]

# %%
def histogram(column) :
    trace1 = go.Histogram(x  = churn[column],
                          histnorm= "percent",
                          name = "Churn Customers",
                          marker = dict(line = dict(width = .5, color = "black")), opacity = .6) 
    
    trace2 = go.Histogram(x  = not_churn[column],
                          histnorm = "percent",
                          name = "Non churn customers",
                          marker = dict(line = dict(width = .5, color = "black" )), opacity = .6)
    
    data = [trace1,trace2]
    layout = go.Layout(dict(plot_bgcolor  = "rgb(243,243,243)",
                            paper_bgcolor = "rgb(243,243,243)",
                            xaxis = dict(gridcolor = 'rgb(255, 255, 255)',
                                             title = column,
                                             zerolinewidth=1,
                                             ticklen=5,
                                             gridwidth=2),
                            yaxis = dict(gridcolor = 'rgb(255, 255, 255)',
                                             title = "percent",
                                             zerolinewidth=1,
                                             ticklen=5,
                                             gridwidth=2),))
    fig  = go.Figure(data=data,layout=layout)
    
    py.iplot(fig)

# %%
histogram('Age')
# Out:
# <div>
#
#
#             <div id="77830cdc-a7e8-4ea6-b9d1-ebfb3390995e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("77830cdc-a7e8-4ea6-b9d1-ebfb3390995e")) {
#                     Plotly.newPlot(
#                         '77830cdc-a7e8-4ea6-b9d1-ebfb3390995e',
# ...

# %% [markdown]
# ### Wizualizacja danych przestrzennych

# %%
# !pip install geopandas #instalacja biblioteki do analiz przestrzennych

# %%
import geopandas

# %% [markdown]
# #### Wczytanie danych przestrzennych

# %%
df_p = geopandas.read_file("data/Powiaty.shp") # plik z geometrią powiatów

# %% [markdown]
# #### Wczytanie i przetworzenie danych GUS dotyczących dotacji z budżetu państwa

# %%
gus_all = pd.read_csv('data/dane_1.csv',delimiter=';',dtype ={'Kod':'str','Nazwa':'str','Rok':'int','Wartosc':'str'})
gus_all['Kod_s']=gus_all['Kod'].astype('str').str.slice(start=0, stop=4)
gus_all['Wartosc']=gus_all['Wartosc'].str.replace(',', '.').astype('float')/1000000

gus=gus_all[gus_all['Rok']==2014].copy()

# %% [markdown]
# #### Funkcja łącząca zbiory i przygotowująca wizualizacje

# %%
def plot_choropleth(year=2014):
    gus=gus_all[gus_all['Rok']==year].copy()
    
    df_merged=df_p.merge(gus,left_on='JPT_KOD_JE', right_on='Kod_s', how='left')
    df_merged['Wartosc'].fillna(0,inplace=True)
    
    df_merged.plot(figsize=(20,10),column='Wartosc', cmap='YlOrBr',legend=True, vmin=0,vmax=300)

# %%
plot_choropleth(year=2014)
